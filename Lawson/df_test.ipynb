# %%
from pathlib import Path
import pandas as pd
import os
import csv
import numpy as np
import requests
import time
import io
import yfinance as yf
import warnings
# Initial imports
#%tensorflow_version 1.x
import tensorflow
import mibian
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import lstm
import psutil
psutil.virtual_memory()
# Out:
# svmem(total=17073303552, available=4073226240, percent=76.1, used=13000077312, free=4073226240)

# %%
mf = pd.read_pickle('etf_MTUM_LSTM.pickle')
mf
# Out:
#               Actual     Predicted  Positive Actual signal  \
# DataDate
# 2019-02-12  0.007110  8.025547e-07                       1
# 2019-02-13 -0.001901  8.025547e-07                       0
# 2019-02-14  0.000000  8.025547e-07                       0
# 2019-02-15 -0.002176  8.025547e-07                       0
# 2019-02-19  0.002545  8.025547e-07                       1
# ...              ...           ...                     ...
# 2019-12-12 -0.003901  8.025547e-07                       0
# 2019-12-13  0.001599  8.025547e-07                       1
# 2019-12-16  0.003272  8.025547e-07                       1
# 2019-12-17  0.001511  8.025547e-07                       1
# 2019-12-18 -0.004924  8.025547e-07                       0
#
#             Negative Actual signal  Positive Predicted signal  \
# DataDate
# 2019-02-12                       0                          1
# 2019-02-13                      -1                          1
# 2019-02-14                       0                          1
# 2019-02-15                      -1                          1
# 2019-02-19                       0                          1
# ...                            ...                        ...
# 2019-12-12                      -1                          1
# 2019-12-13                       0                          1
# 2019-12-16                       0                          1
# 2019-12-17                       0                          1
# 2019-12-18                      -1                          1
#
#             Negative Predicted signal  Actual Signal  LSTM Predicted Signal
# DataDate
# 2019-02-12                          0              1                      1
# 2019-02-13                          0             -1                      1
# 2019-02-14                          0              0                      1
# 2019-02-15                          0             -1                      1
# 2019-02-19                          0              1                      1
# ...                               ...            ...                    ...
# 2019-12-12                          0             -1                      1
# 2019-12-13                          0              1                      1
# 2019-12-16                          0              1                      1
# 2019-12-17                          0              1                      1
# 2019-12-18                          0             -1                      1
#
# [204 rows x 8 columns]

# %%
##This is a place holder, the real dataframe we load will have the signals already implemented
df.to_csv('tech_AAPL_signal_ready.csv')

# %%
mf = pd.read_pickle("finance_JPM_signaled.pickle")
mf
# Out:
#                                 optionkey Symbol ExpirationDate AskPrice  \
# 2018-10-12  GS2018-10-12c192.502018-10-12     GS     2018-10-12    23.50
# 2018-10-12  GS2018-10-12p192.502018-10-12     GS     2018-10-12     1.35
# 2018-10-12  GS2018-10-12c195.002018-10-12     GS     2018-10-12    20.95
# 2018-10-12  GS2018-10-12p195.002018-10-12     GS     2018-10-12     0.25
# 2018-10-12  GS2018-10-12p197.502018-10-12     GS     2018-10-12     2.38
# ...                                   ...    ...            ...      ...
# 2019-12-18  JPM2022-01-21P75.002019-12-18    JPM     2022-01-21     2.75
# 2019-12-18  JPM2022-01-21P80.002019-12-18    JPM     2022-01-21     3.30
# 2019-12-18  JPM2022-01-21P85.002019-12-18    JPM     2022-01-21     3.90
# 2019-12-18  JPM2022-01-21P90.002019-12-18    JPM     2022-01-21     4.75
# 2019-12-18  JPM2022-01-21P95.002019-12-18    JPM     2022-01-21     5.50
#
#            AskSize BidPrice BidSize LastPrice PutCall  StrikePrice Volume  \
# 2018-10-12      20    19.65      20      0.00    call        192.5      0
# 2018-10-12      30     0.00       0      0.02     put        192.5      0
# 2018-10-12      20    17.15      20      0.00    call        195.0      0
# 2018-10-12       2     0.00       0      0.03     put        195.0      0
# 2018-10-12      10     0.00       0      0.07     put        197.5      0
# ...            ...      ...     ...       ...     ...          ...    ...
# 2019-12-18      25     1.50      20      2.17     put         75.0      0
# 2019-12-18      25     1.76      25      3.27     put         80.0      0
# 2019-12-18      25     2.33      20      2.28     put         85.0      0
# 2019-12-18      66     3.00      20      4.10     put         90.0      0
# 2019-12-18      40     3.85      20      4.70     put         95.0      0
#
#            openinterest  UnderlyingPrice       Date time delta     % out  \
# 2018-10-12            0           213.83 2018-10-12     0 days -0.099752
# 2018-10-12            5           213.83 2018-10-12     0 days -0.099752
# 2018-10-12            0           213.83 2018-10-12     0 days -0.088061
# 2018-10-12            2           213.83 2018-10-12     0 days -0.088061
# 2018-10-12           65           213.83 2018-10-12     0 days -0.076369
# ...                 ...              ...        ...        ...       ...
# 2019-12-18          470           138.04 2019-12-18   765 days -0.456679
# 2019-12-18          364           138.04 2019-12-18   765 days -0.420458
# 2019-12-18          144           138.04 2019-12-18   765 days -0.384236
# 2019-12-18          751           138.04 2019-12-18   765 days -0.348015
# 2019-12-18         1597           138.04 2019-12-18   765 days -0.311794
#
#              exp?               DateKey  LSTM Predicted Signal  \
# 2018-10-12   True  2018-10-122018-10-12                     -1
# 2018-10-12   True  2018-10-122018-10-12                     -1
# 2018-10-12   True  2018-10-122018-10-12                     -1
# 2018-10-12   True  2018-10-122018-10-12                     -1
# 2018-10-12   True  2018-10-122018-10-12                     -1
# ...           ...                   ...                    ...
# 2019-12-18  False  2019-12-182022-01-21                     -1
# 2019-12-18  False  2019-12-182022-01-21                     -1
# 2019-12-18  False  2019-12-182022-01-21                     -1
# 2019-12-18  False  2019-12-182022-01-21                     -1
# 2019-12-18  False  2019-12-182022-01-21                     -1
#
#             RF Predicted Value
# 2018-10-12                   1
# 2018-10-12                   1
# 2018-10-12                   1
# 2018-10-12                   1
# 2018-10-12                   1
# ...                        ...
# 2019-12-18                   1
# 2019-12-18                   1
# 2019-12-18                   1
# 2019-12-18                   1
# 2019-12-18                   1
#
# [562415 rows x 20 columns]

# %%
df = pd.read_pickle('tech_AAPL_signal_ready.pickle')
df
# Out:
#                                  optionkey Symbol ExpirationDate AskPrice  \
# 2018-10-15  MSFT2018-10-19c55.002018-10-15   MSFT     2018-10-19    52.90
# 2018-10-15  MSFT2018-10-19p55.002018-10-15   MSFT     2018-10-19     0.03
# 2018-10-15  MSFT2018-10-19c60.002018-10-15   MSFT     2018-10-19    50.10
# 2018-10-15  MSFT2018-10-19p60.002018-10-15   MSFT     2018-10-19     0.01
# 2018-10-15  MSFT2018-10-19c65.002018-10-15   MSFT     2018-10-19    45.10
# ...                                    ...    ...            ...      ...
# 2019-12-18    FB2022-01-21P75.002019-12-18     FB     2022-01-21     4.75
# 2019-12-18    FB2022-01-21P80.002019-12-18     FB     2022-01-21     4.75
# 2019-12-18    FB2022-01-21P85.002019-12-18     FB     2022-01-21     4.75
# 2019-12-18    FB2022-01-21P90.002019-12-18     FB     2022-01-21     5.70
# 2019-12-18    FB2022-01-21P95.002019-12-18     FB     2022-01-21     4.80
#
#            AskSize BidPrice BidSize LastPrice PutCall  StrikePrice Volume  \
# 2018-10-15       8    50.60      36     26.40    call         55.0      0
# 2018-10-15     136     0.00       0      0.01     put         55.0      0
# 2018-10-15      10    45.80      36     23.95    call         60.0      0
# 2018-10-15     199     0.00       0      0.01     put         60.0      0
# 2018-10-15      10    41.05      12     23.91    call         65.0      0
# ...            ...      ...     ...       ...     ...          ...    ...
# 2019-12-18       1        0       0      0.80     put         75.0      0
# 2019-12-18       1        0       0      1.30     put         80.0      0
# 2019-12-18       1        0       0      1.30     put         85.0     20
# 2019-12-18       4     1.30       1      1.75     put         90.0      0
# 2019-12-18       3     0.35       1      2.00     put         95.0      3
#
#            openinterest  UnderlyingPrice       Date time delta     % out  \
# 2018-10-15          443           107.57 2018-10-15     4 days -0.488705
# 2018-10-15          120           107.57 2018-10-15     4 days -0.488705
# 2018-10-15           12           107.57 2018-10-15     4 days -0.442224
# 2018-10-15          628           107.57 2018-10-15     4 days -0.442224
# 2018-10-15          132           107.57 2018-10-15     4 days -0.395742
# ...                 ...              ...        ...        ...       ...
# 2019-12-18           11           202.50 2019-12-18   765 days -0.629630
# 2019-12-18          105           202.50 2019-12-18   765 days -0.604938
# 2019-12-18            4           202.50 2019-12-18   765 days -0.580247
# 2019-12-18           24           202.50 2019-12-18   765 days -0.555556
# 2019-12-18           70           202.50 2019-12-18   765 days -0.530864
#
#              exp?               DateKey  LSTM Predicted Signal  \
# 2018-10-15  False  2018-10-152018-10-19                      1
# 2018-10-15  False  2018-10-152018-10-19                      1
# 2018-10-15  False  2018-10-152018-10-19                      1
# 2018-10-15  False  2018-10-152018-10-19                      1
# 2018-10-15  False  2018-10-152018-10-19                      1
# ...           ...                   ...                    ...
# 2019-12-18  False  2019-12-182022-01-21                      1
# 2019-12-18  False  2019-12-182022-01-21                      1
# 2019-12-18  False  2019-12-182022-01-21                      1
# 2019-12-18  False  2019-12-182022-01-21                      1
# 2019-12-18  False  2019-12-182022-01-21                      1
#
#             RF Predicted Value
# 2018-10-15                   1
# 2018-10-15                   1
# 2018-10-15                   1
# 2018-10-15                   1
# 2018-10-15                   1
# ...                        ...
# 2019-12-18                   1
# 2019-12-18                   1
# 2019-12-18                   1
# 2019-12-18                   1
# 2019-12-18                   1
#
# [3044464 rows x 20 columns]

# %%
df['optionkey'] = df['optionkey'].map(lambda x:str(x)[:-10])
df
# Out:
#                        optionkey Symbol ExpirationDate AskPrice AskSize  \
# 2018-10-15  MSFT2018-10-19c55.00   MSFT     2018-10-19    52.90       8
# 2018-10-15  MSFT2018-10-19p55.00   MSFT     2018-10-19     0.03     136
# 2018-10-15  MSFT2018-10-19c60.00   MSFT     2018-10-19    50.10      10
# 2018-10-15  MSFT2018-10-19p60.00   MSFT     2018-10-19     0.01     199
# 2018-10-15  MSFT2018-10-19c65.00   MSFT     2018-10-19    45.10      10
# ...                          ...    ...            ...      ...     ...
# 2019-12-18    FB2022-01-21P75.00     FB     2022-01-21     4.75       1
# 2019-12-18    FB2022-01-21P80.00     FB     2022-01-21     4.75       1
# 2019-12-18    FB2022-01-21P85.00     FB     2022-01-21     4.75       1
# 2019-12-18    FB2022-01-21P90.00     FB     2022-01-21     5.70       4
# 2019-12-18    FB2022-01-21P95.00     FB     2022-01-21     4.80       3
#
#            BidPrice BidSize LastPrice PutCall  StrikePrice Volume  \
# 2018-10-15    50.60      36     26.40    call         55.0      0
# 2018-10-15     0.00       0      0.01     put         55.0      0
# 2018-10-15    45.80      36     23.95    call         60.0      0
# 2018-10-15     0.00       0      0.01     put         60.0      0
# 2018-10-15    41.05      12     23.91    call         65.0      0
# ...             ...     ...       ...     ...          ...    ...
# 2019-12-18        0       0      0.80     put         75.0      0
# 2019-12-18        0       0      1.30     put         80.0      0
# 2019-12-18        0       0      1.30     put         85.0     20
# 2019-12-18     1.30       1      1.75     put         90.0      0
# 2019-12-18     0.35       1      2.00     put         95.0      3
#
#            openinterest  UnderlyingPrice       Date time delta     % out  \
# 2018-10-15          443           107.57 2018-10-15     4 days -0.488705
# 2018-10-15          120           107.57 2018-10-15     4 days -0.488705
# 2018-10-15           12           107.57 2018-10-15     4 days -0.442224
# 2018-10-15          628           107.57 2018-10-15     4 days -0.442224
# 2018-10-15          132           107.57 2018-10-15     4 days -0.395742
# ...                 ...              ...        ...        ...       ...
# 2019-12-18           11           202.50 2019-12-18   765 days -0.629630
# 2019-12-18          105           202.50 2019-12-18   765 days -0.604938
# 2019-12-18            4           202.50 2019-12-18   765 days -0.580247
# 2019-12-18           24           202.50 2019-12-18   765 days -0.555556
# 2019-12-18           70           202.50 2019-12-18   765 days -0.530864
#
#              exp?               DateKey  LSTM Predicted Signal  \
# 2018-10-15  False  2018-10-152018-10-19                      1
# 2018-10-15  False  2018-10-152018-10-19                      1
# 2018-10-15  False  2018-10-152018-10-19                      1
# 2018-10-15  False  2018-10-152018-10-19                      1
# 2018-10-15  False  2018-10-152018-10-19                      1
# ...           ...                   ...                    ...
# 2019-12-18  False  2019-12-182022-01-21                      1
# 2019-12-18  False  2019-12-182022-01-21                      1
# 2019-12-18  False  2019-12-182022-01-21                      1
# 2019-12-18  False  2019-12-182022-01-21                      1
# 2019-12-18  False  2019-12-182022-01-21                      1
#
#             RF Predicted Value
# 2018-10-15                   1
# 2018-10-15                   1
# 2018-10-15                   1
# 2018-10-15                   1
# 2018-10-15                   1
# ...                        ...
# 2019-12-18                   1
# 2019-12-18                   1
# 2019-12-18                   1
# 2019-12-18                   1
# 2019-12-18                   1
#
# [3044464 rows x 20 columns]

# %%
df = map_exp(df) 
df['profit'] = df['AskPrice'].astype(float) - df['xp'].astype(float)
df['profit'].nunique()
# Out:
# 39055

# %%
mf
# Out:
#                                  optionkey Symbol ExpirationDate AskPrice  \
# 2018-10-15  MSFT2018-10-19c55.002018-10-15   MSFT     2018-10-19    52.90
# 2018-10-15  MSFT2018-10-19p55.002018-10-15   MSFT     2018-10-19     0.03
# 2018-10-15  MSFT2018-10-19c60.002018-10-15   MSFT     2018-10-19    50.10
# 2018-10-15  MSFT2018-10-19p60.002018-10-15   MSFT     2018-10-19     0.01
# 2018-10-15  MSFT2018-10-19c65.002018-10-15   MSFT     2018-10-19    45.10
# ...                                    ...    ...            ...      ...
# 2019-12-18    FB2022-01-21P75.002019-12-18     FB     2022-01-21     4.75
# 2019-12-18    FB2022-01-21P80.002019-12-18     FB     2022-01-21     4.75
# 2019-12-18    FB2022-01-21P85.002019-12-18     FB     2022-01-21     4.75
# 2019-12-18    FB2022-01-21P90.002019-12-18     FB     2022-01-21     5.70
# 2019-12-18    FB2022-01-21P95.002019-12-18     FB     2022-01-21     4.80
#
#            AskSize BidPrice BidSize LastPrice PutCall  StrikePrice Volume  \
# 2018-10-15       8    50.60      36     26.40    call         55.0      0
# 2018-10-15     136     0.00       0      0.01     put         55.0      0
# 2018-10-15      10    45.80      36     23.95    call         60.0      0
# 2018-10-15     199     0.00       0      0.01     put         60.0      0
# 2018-10-15      10    41.05      12     23.91    call         65.0      0
# ...            ...      ...     ...       ...     ...          ...    ...
# 2019-12-18       1        0       0      0.80     put         75.0      0
# 2019-12-18       1        0       0      1.30     put         80.0      0
# 2019-12-18       1        0       0      1.30     put         85.0     20
# 2019-12-18       4     1.30       1      1.75     put         90.0      0
# 2019-12-18       3     0.35       1      2.00     put         95.0      3
#
#            openinterest  UnderlyingPrice       Date time delta     % out  \
# 2018-10-15          443           107.57 2018-10-15     4 days -0.488705
# 2018-10-15          120           107.57 2018-10-15     4 days -0.488705
# 2018-10-15           12           107.57 2018-10-15     4 days -0.442224
# 2018-10-15          628           107.57 2018-10-15     4 days -0.442224
# 2018-10-15          132           107.57 2018-10-15     4 days -0.395742
# ...                 ...              ...        ...        ...       ...
# 2019-12-18           11           202.50 2019-12-18   765 days -0.629630
# 2019-12-18          105           202.50 2019-12-18   765 days -0.604938
# 2019-12-18            4           202.50 2019-12-18   765 days -0.580247
# 2019-12-18           24           202.50 2019-12-18   765 days -0.555556
# 2019-12-18           70           202.50 2019-12-18   765 days -0.530864
#
#              exp?               DateKey  LSTM Predicted Signal  \
# 2018-10-15  False  2018-10-152018-10-19                      1
# 2018-10-15  False  2018-10-152018-10-19                      1
# 2018-10-15  False  2018-10-152018-10-19                      1
# 2018-10-15  False  2018-10-152018-10-19                      1
# 2018-10-15  False  2018-10-152018-10-19                      1
# ...           ...                   ...                    ...
# 2019-12-18  False  2019-12-182022-01-21                      1
# 2019-12-18  False  2019-12-182022-01-21                      1
# 2019-12-18  False  2019-12-182022-01-21                      1
# 2019-12-18  False  2019-12-182022-01-21                      1
# 2019-12-18  False  2019-12-182022-01-21                      1
#
#             RF Predicted Value
# 2018-10-15                   1
# 2018-10-15                   1
# 2018-10-15                   1
# 2018-10-15                   1
# 2018-10-15                   1
# ...                        ...
# 2019-12-18                   1
# 2019-12-18                   1
# 2019-12-18                   1
# 2019-12-18                   1
# 2019-12-18                   1
#
# [3044464 rows x 20 columns]

# %%
mf['optionkey'] = mf['optionkey'][:-10]
mf

# %%
df['optionkey'].sort_values()
# Out:
# 2018-10-15    AAPL2018-10-19c10.002018-10-15
# 2018-10-16    AAPL2018-10-19c10.002018-10-16
# 2018-10-17    AAPL2018-10-19c10.002018-10-17
# 2018-10-18    AAPL2018-10-19c10.002018-10-18
# 2018-10-19    AAPL2018-10-19c10.002018-10-19
#                            ...
# 2019-09-30    TSLA2022-01-21p75.002019-09-30
# 2019-09-30    TSLA2022-01-21p80.002019-09-30
# 2019-09-30    TSLA2022-01-21p85.002019-09-30
# 2019-09-30    TSLA2022-01-21p90.002019-09-30
# 2019-09-30    TSLA2022-01-21p95.002019-09-30
# Name: optionkey, Length: 3044464, dtype: object

# %%
df['xp'].nunique()
# Out:
# 6935

# %%
## Can you figure this out?

#fix this so that the .nunique() prints out more unique values of the column
fy = df
fy['profit'] = fy['AskPrice'].astype(float) - fy['xp'].astype(float)
fy['profit'].nunique()
# Out:
# 1

# %%
fy
# Out:
#                                  optionkey Symbol ExpirationDate AskPrice  \
# 2018-10-15  MSFT2018-10-19c55.002018-10-15   MSFT     2018-10-19    52.90
# 2018-10-15  MSFT2018-10-19p55.002018-10-15   MSFT     2018-10-19     0.03
# 2018-10-15  MSFT2018-10-19c60.002018-10-15   MSFT     2018-10-19    50.10
# 2018-10-15  MSFT2018-10-19p60.002018-10-15   MSFT     2018-10-19     0.01
# 2018-10-15  MSFT2018-10-19c65.002018-10-15   MSFT     2018-10-19    45.10
# ...                                    ...    ...            ...      ...
# 2019-12-18    FB2022-01-21P75.002019-12-18     FB     2022-01-21     4.75
# 2019-12-18    FB2022-01-21P80.002019-12-18     FB     2022-01-21     4.75
# 2019-12-18    FB2022-01-21P85.002019-12-18     FB     2022-01-21     4.75
# 2019-12-18    FB2022-01-21P90.002019-12-18     FB     2022-01-21     5.70
# 2019-12-18    FB2022-01-21P95.002019-12-18     FB     2022-01-21     4.80
#
#            AskSize BidPrice BidSize LastPrice PutCall  StrikePrice  ...  \
# 2018-10-15       8    50.60      36     26.40    call         55.0  ...
# 2018-10-15     136     0.00       0      0.01     put         55.0  ...
# 2018-10-15      10    45.80      36     23.95    call         60.0  ...
# 2018-10-15     199     0.00       0      0.01     put         60.0  ...
# 2018-10-15      10    41.05      12     23.91    call         65.0  ...
# ...            ...      ...     ...       ...     ...          ...  ...
# 2019-12-18       1        0       0      0.80     put         75.0  ...
# 2019-12-18       1        0       0      1.30     put         80.0  ...
# 2019-12-18       1        0       0      1.30     put         85.0  ...
# 2019-12-18       4     1.30       1      1.75     put         90.0  ...
# 2019-12-18       3     0.35       1      2.00     put         95.0  ...
#
#            UnderlyingPrice       Date  time delta     % out   exp?  \
# 2018-10-15          107.57 2018-10-15      4 days -0.488705  False
# 2018-10-15          107.57 2018-10-15      4 days -0.488705  False
# 2018-10-15          107.57 2018-10-15      4 days -0.442224  False
# 2018-10-15          107.57 2018-10-15      4 days -0.442224  False
# 2018-10-15          107.57 2018-10-15      4 days -0.395742  False
# ...                    ...        ...         ...       ...    ...
# 2019-12-18          202.50 2019-12-18    765 days -0.629630  False
# 2019-12-18          202.50 2019-12-18    765 days -0.604938  False
# 2019-12-18          202.50 2019-12-18    765 days -0.580247  False
# 2019-12-18          202.50 2019-12-18    765 days -0.555556  False
# 2019-12-18          202.50 2019-12-18    765 days -0.530864  False
#
#                          DateKey  LSTM Predicted Signal RF Predicted Value  \
# 2018-10-15  2018-10-152018-10-19                      1                  1
# 2018-10-15  2018-10-152018-10-19                      1                  1
# 2018-10-15  2018-10-152018-10-19                      1                  1
# 2018-10-15  2018-10-152018-10-19                      1                  1
# 2018-10-15  2018-10-152018-10-19                      1                  1
# ...                          ...                    ...                ...
# 2019-12-18  2019-12-182022-01-21                      1                  1
# 2019-12-18  2019-12-182022-01-21                      1                  1
# 2019-12-18  2019-12-182022-01-21                      1                  1
# 2019-12-18  2019-12-182022-01-21                      1                  1
# 2019-12-18  2019-12-182022-01-21                      1                  1
#
#              xp  profit
# 2018-10-15  NaN     NaN
# 2018-10-15  NaN     NaN
# 2018-10-15  NaN     NaN
# 2018-10-15  NaN     NaN
# 2018-10-15  NaN     NaN
# ...         ...     ...
# 2019-12-18  NaN     NaN
# 2019-12-18  NaN     NaN
# 2019-12-18  NaN     NaN
# 2019-12-18  NaN     NaN
# 2019-12-18  NaN     NaN
#
# [3044464 rows x 22 columns]

# %%
fy.dropna(subset=['xp'])
# Out:
#                                 optionkey Symbol ExpirationDate AskPrice  \
# 2019-12-13  FB2019-12-13P235.002019-12-13     FB     2019-12-13    43.15
# 2019-12-13  FB2019-12-13P237.502019-12-13     FB     2019-12-13    45.70
# 2019-12-13  FB2019-12-13P240.002019-12-13     FB     2019-12-13    48.15
# 2019-12-13  FB2019-12-13P245.002019-12-13     FB     2019-12-13    53.15
# 2019-12-13  FB2019-12-13P250.002019-12-13     FB     2019-12-13    58.20
#
#            AskSize BidPrice BidSize LastPrice PutCall  StrikePrice  ...  \
# 2019-12-13      10    38.80      11         0     put        235.0  ...
# 2019-12-13      11    41.40      10     41.40     put        237.5  ...
# 2019-12-13      10    43.70      12     40.55     put        240.0  ...
# 2019-12-13      10    48.70      12     45.45     put        245.0  ...
# 2019-12-13      11    53.90      10     47.50     put        250.0  ...
#
#            UnderlyingPrice       Date  time delta     % out  exp?  \
# 2019-12-13          194.11 2019-12-13      0 days  0.210654  True
# 2019-12-13          194.11 2019-12-13      0 days  0.223533  True
# 2019-12-13          194.11 2019-12-13      0 days  0.236412  True
# 2019-12-13          194.11 2019-12-13      0 days  0.262171  True
# 2019-12-13          194.11 2019-12-13      0 days  0.287930  True
#
#                          DateKey  LSTM Predicted Signal RF Predicted Value  \
# 2019-12-13  2019-12-132019-12-13                      1                  1
# 2019-12-13  2019-12-132019-12-13                      1                  1
# 2019-12-13  2019-12-132019-12-13                      1                  1
# 2019-12-13  2019-12-132019-12-13                      1                  1
# 2019-12-13  2019-12-132019-12-13                      1                  1
#
#                xp  profit
# 2019-12-13  43.15     0.0
# 2019-12-13  45.70     0.0
# 2019-12-13  48.15     0.0
# 2019-12-13  53.15     0.0
# 2019-12-13  58.20     0.0
#
# [5 rows x 22 columns]

# %%
fy['optionkey'].str[-6:]
# Out:
# 2018-10-15    -10-15
# 2018-10-15    -10-15
# 2018-10-15    -10-15
# 2018-10-15    -10-15
# 2018-10-15    -10-15
#                ...
# 2019-12-18    -12-18
# 2019-12-18    -12-18
# 2019-12-18    -12-18
# 2019-12-18    -12-18
# 2019-12-18    -12-18
# Name: optionkey, Length: 3044464, dtype: object

# %%
fy['profit'].nunique()
# Out:
# 1

# %%
def test_reducer(df):
    df = df.drop(colums# all unneded columns should be dropped)

# %%
df = test_reducer(df)
df = select_df(df)

# %%
calls = create_call_targets(df)
calls
# Out:
# C:\Users\austi\anaconda3\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\austi\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-8-b1f9e021e78c> in <module>
# ----> 1 calls = create_call_targets(df)
#       2 calls
#
# <ipython-input-7-ea5330a669a9> in create_call_targets(df)
#      21 def create_call_targets(df): #, atm, ctm, otm, xf, xm, xs
#      22     df = select_df(df, 'call')
# ---> 23     df = map_exp(df)
#      24     df['atm_xf'] = df['time delta'] < np.timedelta64(xf, 'D') & (df['% out'] > -.01) & (df['% out'] < atm)
#      25     df['ctm_xf'] = df['time delta'] < np.timedelta64(xf, 'D') & (df['% out'] > atm) & (df['% out'] < ctm)
#
# <ipython-input-7-ea5330a669a9> in map_exp(df)
#      59     xp = xp.loc[xp['exp?']== True]
#      60     xp= xp[['optionkey', 'xp']]
# ---> 61     df['xp']=df.optionkey.map(xp.set_index('optionkey')['xp'])
#      62     return df
#      63
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3877         dtype: object
#    3878         """
# -> 3879         new_values = super()._map_values(arg, na_action=na_action)
#    3880         return self._constructor(new_values, index=self.index).__finalize__(
#    3881             self, method="map"
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#     905             values = self._values
#     906
# --> 907             indexer = mapper.index.get_indexer(values)
#     908             new_values = algorithms.take_1d(mapper._values, indexer)
#     909
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    3169
#    3170         if not self.is_unique:
# -> 3171             raise InvalidIndexError(
#    3172                 "Reindexing only valid with uniquely valued Index objects"
#    3173             )
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
### Change %out an absolute value, put signals out of the money are going to be negatives
### Or create multipliers of -1 for put targets

##

#atm = at the money
#ctm = close to the money
#otm = out of the money
#ftm = further out of the money
#xf = expire far
#xm = expiring medium's distance
#xs = expiring soon

atm = .07
ctm = .1
otm = .15
ftm = .2
xf = 28
xm = 19
xs = 7
def create_call_targets(df): #, atm, ctm, otm, xf, xm, xs
    df = select_df(df, 'call')
    df = map_exp(df)
    df['atm_xf'] = df['time delta'] < np.timedelta64(xf, 'D') & (df['% out'] > -.01) & (df['% out'] < atm)
    df['ctm_xf'] = df['time delta'] < np.timedelta64(xf, 'D') & (df['% out'] > atm) & (df['% out'] < ctm)
    df['otm_xf'] = df['time delta'] < np.timedelta64(xf, 'D') & (df['% out'] > ctm) & (df['% out'] < otm)
    df['ftm_xf'] = df['time delta'] < np.timedelta64(xf, 'D') & (df['% out'] > otm) & (df['% out'] < ftm)
    df['atm_xm'] = df['time delta'] < np.timedelta64(xm, 'D') & (df['% out'] > 0) & (df['% out'] < atm)
    df['ctm_xm'] = df['time delta'] < np.timedelta64(xm, 'D') & (df['% out'] > atm) & (df['% out'] < ctm)
    df['otm_xm'] = df['time delta'] < np.timedelta64(xm, 'D') & (df['% out'] > ctm) & (df['% out'] < otm)
    df['ftm_xm'] = df['time delta'] < np.timedelta64(xm, 'D') & (df['% out'] > otm) & (df['% out'] < ftm)
    df['atm_xs'] = df['time delta'] < np.timedelta64(xs, 'D') & (df['% out'] > 0) & (df['% out'] < atm)
    df['ctm_xs'] = df['time delta'] < np.timedelta64(xs, 'D') & (df['% out'] > atm) & (df['% out'] < ctm)
    df['otm_xs'] = df['time delta'] < np.timedelta64(xs, 'D') & (df['% out'] > ctm) & (df['% out'] < otm)
    return df

def create_put_targets(df, atm, ctm, otm, xf, xm, xs):
    df['atm_xf'] = df['time delta'] < np.timedelta64(xf, 'D') & (df['% out'] > .01) & (df['% out'] < (-1 * atm))
    df['ctm_xf'] = df['time delta'] < np.timedelta64(xf, 'D') & (df['% out'] > (-1 * atm)) & (df['% out'] < (-1 * ctm))
    df['otm_xf'] = df['time delta'] < np.timedelta64(xf, 'D') & (df['% out'] > (-1 * ctm)) & (df['% out'] < (-1 * otm))
    df['ftm_xf'] = df['time delta'] < np.timedelta64(xf, 'D') & (df['% out'] > (-1 * otm)) & (df['% out'] < (-1 * ftm))
    df['atm_xm'] = df['time delta'] < np.timedelta64(xm, 'D') & (df['% out'] >  0) & (df['% out'] < (-1 * atm))
    df['ctm_xm'] = df['time delta'] < np.timedelta64(xm, 'D') & (df['% out'] > (-1 * atm)) & (df['% out'] < (-1 * ctm))
    df['otm_xm'] = df['time delta'] < np.timedelta64(xm, 'D') & (df['% out'] > (-1 * ctm)) & (df['% out'] < (-1 * otm))
    df['ftm_xm'] = df['time delta'] < np.timedelta64(xm, 'D') & (df['% out'] > (-1 * otm)) & (df['% out'] < (-1 * ftm))
    df['atm_xs'] = df['time delta'] < np.timedelta64(xs, 'D') & (df['% out'] > (-1 * 0) )& (df['% out'] <(-1 *  atm))
    df['ctm_xs'] = df['time delta'] < np.timedelta64(xs, 'D') & (df['% out'] > (-1 * atm)) & (df['% out'] < (-1 * ctm))
    df['otm_xs'] = df['time delta'] < np.timedelta64(xs, 'D') & (df['% out'] > (-1 * ctm)) & (df['% out'] < (-1 * otm))
    return df

def select_df(df, option): #symbol choice
    df = df.loc[df['PutCall'] == option]
    #df = df.loc[df['Symbol'] == symbol]
    return df

def map_exp(df):
    xp = df
    xp.loc[xp['exp?']== True, 'xp' ] = xp.loc[df['exp?'] == True, 'AskPrice']
    xp = xp.loc[xp['exp?']== True]
    xp= xp[['optionkey', 'xp']]
    df['xp']=df.optionkey.map(xp.set_index('optionkey')['xp'])
    return df


def create_spreads(data):
    #Sort Values and shift to set up collateral requirements
    data['DateKey']=data['DataDate'].astype('str')+data['ExpirationDate'].astype('str') 
    data.groupby('DateKey') 
    data.sort_values('DataDate') 
    data['Prev_Strike']=data['StrikePrice'].shift(1)
    data['Prev_AskPrice']=data['AskPrice'].shift(1)
    data['Prev_DateKey']=data['DateKey'].shift(1)

    # Create nan values where the shifted value uses a different day
    for i in data.index:
        if data.loc[i, 'Prev_DateKey']!=data.loc[i, 'DateKey']:
            data.loc[i, 'Prev_Strike']=np.nan
            data.loc[i, 'Prev_AskPrice']=np.nan
            
    return data

# %%
#
def prepare_test(df):
    ##using map exp function already built
    df = map_exp(df)
    ## select options or puts df
    df = select_df(df, symbol, option)
    #create spread for potential spread strategy
    df = create_spread(df)

# %%
import itertools
list_strats = ['LM signal' , 'rf_signal',  'put signal', 'bl_1']
cross_list=list(itertools.product(list_strats, list_strats))

def test_print(first, second): 
    print(f'{first} X {second}')
          
for first, second in cross_list: 
    test_print(first, second)
# Out:
# LM signal X LM signal
# LM signal X bol signal
# LM signal X put signal
# LM signal X bl_1
# bol signal X LM signal
# bol signal X bol signal
# bol signal X put signal
# bol signal X bl_1
# put signal X LM signal
# put signal X bol signal
# put signal X put signal
# put signal X bl_1
# bl_1 X LM signal
# bl_1 X bol signal
# bl_1 X put signal
# bl_1 X bl_1

# %%
list_strats = 'LM signal' , 'bol signal',  'put signal', 'bl_1'


def testing(df, x, y):
    
    bl_1_LTSM = df.loc[(df['bl_1']== 1) & (df['LSTM'] == 1)]
    bl_1_LTSM['log'] = bl_1_LTSM['AskPrice'].astype(float) - bl_1_LTSM['BidPrice'].astype(float)
    bl_1_LTSM_total = bl_1_LTSM['log'].sum()
#     bl_1_LTSM = short_close['log'].sum()
    bl_1_LTSM_log = bl_1_LTSM['log']
#     bl_1_LTSM_log_df = pd.DataFrame(bl_1_LTSM, columns = ['log'])
    bl_1_LTSM['log'].to_csv(f'{x} X {y}.csv')
    df['bl_1_LTSM_log'] = bl_1_LTSM['log']
    return df

# %%
def basic_signals(df):
    #define emoty series for br and bl
    br_1 = []
    br_2 = []
    bl_1 = []
    bl_2 = []
    for index, row in df.iterrows():
        # Put signals and bollinger_signal -1 determines bearish signal
        if (row['Put signals'] == True & row['bollinger_signal'] == -1):
            br_1.append(True)
        else:
            br_1.append(False)
        # Put signals and relative volatility 0 determines bearish signal
        if (row['Put signals'] == True & row['rvol signal'] == 0):
            br_2.append(True)
        else:
            br_2.append(False)
        #high volatility + a put/call signal could identify stock movement
        if (row['rvol signal'] == 1 & row['Call signals'] == True):
            bl_1.append(True)
        else:
            bl_1.append(False)
        #Put/call signal and Option rvol signals a bullish movement
        if (row['Call signals'] == True and row['Option rVol'] > 1.4):
            bl_2.append(True)
        else:
            bl_2.append(False)
    #append series columns to dataframe
    df['br_1'] = br_1
    df['br_2'] = br_2
    df['bl_1'] = bl_1
    df['bl_2'] = bl_2
    return df

# %%
###Start appending values and creating csvs
### Do this for every variation

symbol ask  xp boop signal  boop log
tsla   5    7    1              -2
pd. read_csv(tech)
pd['LSTM'] = dummies
   
#add every test to a master frame?
mf = {}
def sell_testing(df):
    bl_1_LTSM = df.loc[(df['bl_1']== True) & (df['LSTM'] == 1)]
    bl_1_LTSM['log'] = bl_1_LTSM['AskPrice'] - bl_1_LTSM['xp']
    bl_1_LTSM_total = bl_1_LTSM['log'].sum()
    bl_1_LTSM = short_close['log'].sum()
    bl_1_LTSM_log = bl_1_LTSM['log'].copy#keep the data date
    bl_1_LTSM_log.to_csv('bl_1_LTSM.csv')

    
def buy_testing(df):
    bl_1_LTSM = df.loc[(df['bl_1']== True) & (df['LSTM'] == 1)]
    bl_1_LTSM['log'] = bl_1_LTSM['xp'] - bl_1_LTSM['AskPrice'] 
    bl_1_LTSM_total = bl_1_LTSM['log'].sum()
    bl_1_LTSM = short_close['log'].sum()
    bl_1_LTSM_log = bl_1_LTSM['log'].copy#keep the data date
    bl_1_LTSM_log.to_csv('bl_1_LTSM.csv')

# %%
#Create signal columns that will enter us in to a strategy


###To be added, when br_1 is true and RF is -1, add 1
###replicate for bl and LTSM



def basic_signals(df):
    #define emoty series for br and bl
    br_1 = []
    br_2 = []
    bl_1 = []
    bl_2 = []
    for index, row in df.iterrows():
        # Put signals and bollinger_signal -1 determines bearish signal
        if (row['Put signals'] == True & row['bollinger_signal'] == -1):
            br_1.append(True)
        else:
            br_1.append(False)
        # Put signals and relative volatility 0 determines bearish signal
        if (row['Put signals'] == True & row['rvol signal'] == 0):
            br_2.append(True)
        else:
            br_2.append(False)
        #high volatility + a put/call signal could identify stock movement
        if (row['rvol signal'] == 1 & row['Call signals'] == True):
            bl_1.append(True)
        else:
            bl_1.append(False)
        #Put/call signal and Option rvol signals a bullish movement
        if (row['Call signals'] == True and row['Option rVol'] > 1.4):
            bl_2.append(True)
        else:
            bl_2.append(False)
    #append series columns to dataframe
    df['br_1'] = br_1
    df['br_2'] = br_2
    df['bl_1'] = bl_1
    df['bl_2'] = bl_2
    return df
